# %% [markdown]
# # IMPORT NECESSARY LIBRARIES

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %% [markdown]
# # scraping data from local business

# %%
# pip install google-play-scraper

# %%
from google_play_scraper import Sort, reviews_all
us_reviews = reviews_all(
    'com.aa.android',
    sleep_milliseconds=0, 
    lang='en', 
    country='in', 
    sort=Sort.NEWEST, 
)

# %%
us_reviews = reviews_all('com.aa.android',sleep_milliseconds=0, lang='en', country='in', sort=Sort.NEWEST)

# %%
us_reviews
# Out:
# [{'reviewId': '7e5f1830-345d-4b88-80c9-4f94b30d7818',
#   'userName': 'Denise Serna',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJitXqroV54aCSbMu9VllEGgwANZ0l-wXPJazKx4dGY=mo',
#   'content': 'Great flight & smooth ride to LAX',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 24, 10, 46, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'be46c94d-88ef-4834-99d2-a97ec26cf51e',
#   'userName': 'Isabella Garcia',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKJgbd5mjlz3Abr3mlu9MIwKI6xjc02Iitrcjdyp6UN=mo',
#   'content': 'Never ever show me information about my flight. Everything is bad in American airlines.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 24, 9, 58, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'd39456f4-6da0-4d48-a463-50d30c0ac995',
#   'userName': 'Jon S',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXWCAVZs30xJiQDhHU8idB_R24UwbQMO-x8mfFS0vBAM1I',
#   'content': "Had to uninstall the app to check-in for my flight. It would not locate the record, and the website kept launching the app which would do nothing. Aught I was logged into my account on the website when I checked in. My trip info isn't present in the app after reinstalling it.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 24, 6, 59, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '0dc819e3-ee8b-44b5-a5e5-cd94937e1195',
#   'userName': 'Kenneth Mckinney',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWgrFM0zszml0ZIso7JCoKw9UyFzVnQvnDhLPk1w_zRhPAY',
#   'content': 'worst company ever',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 24, 6, 0, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'd2ed0d59-027f-40e6-bd74-38776bda4452',
#   'userName': 'Alicia Mendez',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXZoCEPmbPkcu3LyWmO6M1f51884UyL7SG1q9P3KoP8Yqw',
#   'content': 'exceptional landing at DFW this evening by our captain Erin!!!!!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 24, 5, 56, 47),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': 'dd876405-88ae-40ed-96f2-43b8985cb727',
#   'userName': 'John Poggioli',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXbnlFZLV7fiPpJREnf2y3hr2OiwLS0d54tnWaJTRdfR-w',
#   'content': 'Enjoyed the hospitality of AA flying from Ny to tx.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 24, 4, 23, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': 'af61822d-b3b6-401c-9d4b-317040f9f60b',
#   'userName': 'Hannah',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLZCLHduWnpp0l069Gplm9K8kZta4dPBzhP-zCs3YA7=mo',
#   'content': 'Genuinely maddening. I signed up for their frequent flier program and am trying to apply my "AA Advantage" number to my upcoming flights, but despite having signed in at least 10 times at this point, it continues to prompt me to sign up or login, instead of recognizing that I am, in fact, logged in. If the goal of this app is to drive customers to madness and stoke a deep rage towards this company, they\'re doing amazing. Keep it up folks.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 24, 1, 13, 24),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'cf6f2529-6db8-4340-af87-9cc0630419b9',
#   'userName': 'ROOSEVELT JEAN',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLqhnuwhNdx2IZ5mo0j4aVYHgHzgpjMOUWt4TwaKnmc=mo',
#   'content': '09/23/2023 Hi to whom it may concern guys i will like to know went we gonna return to flight back from Miami Florida international airport,1 AA fligh from New York Jfk international Airport to cap Haitien international Airport in Haiti 🇭🇹 guys i guaranteed this is a time to do it because people travel to cap Haitian is the best please..',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 24, 0, 26, 28),
#   'replyContent': 'Thank you! We really appreciate you taking time to share your experience with us.',
#   'repliedAt': datetime.datetime(2021, 6, 21, 21, 30, 56),
#   'appVersion': '2023.16'},
#  {'reviewId': 'cc7995c8-af86-477c-b950-07d988fb5d41',
#   'userName': 'Richard',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIkcFo3E4IWh_fd7GYh3DtawWVE9QIcmEpoeBPWIR3M=mo',
#   'content': 'Difficult to change same day flights. navigation slow with occasional "This page flew away" comment for loading errors.',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 23, 20, 24, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': 'abe73393-d64a-43b3-bc80-b6b700fd3a8a',
#   'userName': 'Alicia Smith',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI1DqS4TweqjvYiqYXsKCvXouRF0gDO81C_4QhTSF5b=mo',
#   'content': "It was difficult to get what I needed. It stunk sorry 😞 but it was rough for me. Thank you I tried Husband did last time we needed something but thanks I'm calling a person. Alicia",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 23, 19, 57, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'f674e95c-423a-46f1-a472-c35db95810df',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Not easy-to-use',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 23, 12, 58, 51),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '57fd0e7f-32f0-49c2-8401-f7f7afbd42e1',
#   'userName': 'Autumn Selle',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJTwwZoA2vctMFzXiwNy1TbuB-GFqelulXr7W6E2k2R=mo',
#   'content': 'I have flown ONE TIME IN MY 39 YEARS and it was literally today from Portland Oregon to Dallas TX so I could get to Wichita KS. FLIGHT 2863 leaving at 11:04pm because it got delayed from 10:40pm. Anyways, on my first flight it went great. They informed me my personal bag goes under my feet, and that was all that was said....no big deal. So when I boarded this time, the guy behind me put his bag under my seat so I politely asked him to move it, then the stuardist became very sarcastic to me!!',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 23, 9, 27, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '2943f2c0-193a-4f74-a177-f1649b58a3ee',
#   'userName': 'Tyler Knox',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWuFRdKKzDq0tWpedwbPUJrBtYwn50Zyt90LONaJrFWz0g',
#   'content': 'Bad airlines has bad app',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.5',
#   'at': datetime.datetime(2023, 9, 23, 7, 21, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.5'},
#  {'reviewId': '9c9849bf-e08f-4f43-9aca-7f4e0885a736',
#   'userName': 'Lucie Anderson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKoGMJhjzwvYgrdGqmRFJ-qsUqIDI95bgl4dZxoXp6U=mo',
#   'content': 'Why can I have a carry in when I need to check it almost every time? AA needs to figure it out.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 23, 5, 10, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '3d4d3f9b-1999-4da3-bbaa-9888acb5a726',
#   'userName': 'J',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL6LqDBXDjwOUtvBOUxI8dk--wT0Yk1Li_QyQ3W60AB=mo',
#   'content': "Got this app to make travel easier for a girls trip. Registered as a new member and haven't been able to get the app to work once. Any time I try to look up my flight it says Error - please try again or come back later. Close the app and try again, same error. Fine... I'll try it from my email. The link in my email opens the app to a blank screen. That's great. Last chance, I got my email to check in and again it opens the app to a blank screen. Eff this, I uninstalled and used their website.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 23, 4, 22, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'fe7d4dfa-a018-4358-bcc8-ea92281b0e28',
#   'userName': 'Peter Joyce',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWXkpXC4LiSW9MM_xupTZyWzlziV-m5bf6LMbjdnLGoAw',
#   'content': 'Lousy',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.13',
#   'at': datetime.datetime(2023, 9, 23, 3, 55, 34),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.13'},
#  {'reviewId': 'fa410c46-706f-40e2-9c69-f262a4ba293c',
#   'userName': 'Todd Trimble',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLjptXIT03RZtBIhtzMh_M9BaooFSc3yAoQeyPVKmbi=mo',
#   'content': 'awesome service',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 23, 2, 48, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '951d1fcf-d2c4-472c-bf12-1d8afaa47891',
#   'userName': 'stephanie gutierrez',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVQeDU_hm1TaoRB9x2UFiaUtOimYDFU1TZafViWTstR10o',
#   'content': 'Kind of difficult to navigate',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 23, 1, 14, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '8b05e6be-ee5b-479d-9cb8-cd87b0b84907',
#   'userName': 'Christla Fontaine (Chrissy)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUCflgBPlJd8GV1RlWZq6xcCwo0Ud5IfLZjeSbTkSd8gDaZ',
#   'content': 'very informative',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 22, 22, 52, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '4ca9d362-1a4f-4148-9043-38d6398d35c2',
#   'userName': 'Chad A',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUFSqINhdB0-QTCYSY5_rZrD-3NuRzLAfFVjd_IjHqJguY',
#   'content': 'smooth and easy',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 22, 22, 27, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '95133d87-3824-4c10-b069-ccf7aa18dead',
#   'userName': 'Nancy Guerriero',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVYluW591804X1NnUqI_mr4SAkcEVub_lup0oKKYegLZnU',
#   'content': 'Continually cannot get real.answers..just Bot',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 22, 22, 4, 16),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '49535910-16b4-4aa1-aabc-eccc576f3d12',
#   'userName': 'Douglas Hayes',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIc5SuJySWZTYLwUzgJRDuZB__Qw_DZ7eKxLDWxBZ0T=mo',
#   'content': 'Excellent app. Very helpful when traveling.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 22, 22, 1, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '312abb27-430b-47e8-83fd-d46a5a7abe91',
#   'userName': 'Rev. Dr. Amos Lawrence Shah',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU72sWAyWXvILXHvOvoo8ME3mG0bZpNZCQaIIF_W2ql75w',
#   'content': 'Excellent!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 22, 21, 45, 25),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'eb341615-e15a-47a4-9983-6c2815962872',
#   'userName': 'Tim Rowan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX9EiYnRUUrOL3WC_w1t0P7Wd2SSxf88JFxzIhwH4s4DkOA',
#   'content': 'Flight attendant Marisa is spectacular. You are lucky to have her.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 22, 10, 12, 14),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '08016b64-0e3b-485d-87de-6a95ea5d4cad',
#   'userName': 'Nelson Rivera',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIubtPtsmV-1J25ZsWnHHe0XfZwVvQQrtutI4_eewI-=mo',
#   'content': 'very unpredictable and unreliable app. The hardest thing to do is when canceling any reservation. It never works. always have to sign on the full website.. seat maps can be unreliable too. And many times the app just stalls/ freezes.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 22, 7, 17, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '9451276c-47db-4558-b1d9-7f9127a3e501',
#   'userName': 'dan gurtovoy',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLXUcix2sbeTUXVmmi6UWLbA2LBwvF8RnSCq01hTj-E=mo',
#   'content': 'great airline',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 22, 3, 23, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'fa0ed8ce-4d4f-498c-b188-f5b558325be6',
#   'userName': 'Steven Heinz',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUlJMzf-hOvHFwfDkRitFTkzKMoGoiPk-IINqds17kAfyhH',
#   'content': 'Have had a good experience over all on American',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 21, 19, 31, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'f0bbdd51-c5be-44b4-a709-6f915250ab92',
#   'userName': 'Daniel Andrus',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWEw6XwIOzc48bmJOaihVd5_eI4cOtu5bhEGA1IO1cEJUg',
#   'content': "9/8/2023: zero stars. I cannot describe how infuriating this app is. It has so many issues I don't even know where to start. Can't process payments. Can't lookup flights with record locator. Can't search for flights. Can't view boarding pass. I'm sure I'm forgetting something. I have to fly often for work and this is by far the worst app I have. Unfortunately they're the only airline operating from my local regional airport.",
#   'score': 1,
#   'thumbsUpCount': 8,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 21, 19, 28, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '1101e156-c455-4bbc-9125-881758d4622b',
#   'userName': 'Wayne Turentine',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIuFtiY-VjhzxhjzTP_BlBbeaTqvC579rzPXEXUxc723Q=mo',
#   'content': 'Nice',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 21, 18, 30, 37),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '90be944e-f635-40c6-a89c-b52fb5c538c4',
#   'userName': 'Max Bachaud (SwiftWing21)',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKUhy6-HuQhkQe9RrDQNKqYM7vjMbtE7H6hIBktQHZI=mo',
#   'content': 'Refresh 100% of the time, do not rely on the app to provide a notice of gate change. 7:00 boarding "started" mobile app still showed GATE B7 on boarding pass. Screen at gate updates for a different flight. Exit boarding pass in the app, force a 3rd consecutive refresh- finally updates and shows gate has changed to C27. Almost missed the ability to board the flight at 7:20 after running 15 minutes across the airport.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 21, 17, 57, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'ea94f282-fe59-4288-bb9d-8ebdb2095f45',
#   'userName': 'Marigrace McKay',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXZWQoriW3aOqMmN6VDv9jMq_hUMp9SMdGGC1cY_GGdFg',
#   'content': 'The app does not find booked flights!',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 21, 14, 58, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '4e149a80-cffd-4a5c-9938-46cf409bec66',
#   'userName': 'David Martin',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUTJMc_a2JSaWpFBLOtHFMD-oYbHOmGh_9HMQlBzgmer0IY',
#   'content': 'Good Airline app.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 21, 12, 21, 29),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '63becf50-5559-4ccb-a4d4-cff4cef9e9d8',
#   'userName': 'Dan Glader',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUC3g94jrCMIuYsQJW0g9ooS-xj_MgXo1klbZjy7NBOKA',
#   'content': 'staff friendly and plane clean....took off late but ended up being early to our destination somehow...good job!',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 21, 7, 48, 49),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '7f4f3ab2-4d90-4f02-a83d-9cd4c51d268c',
#   'userName': 'Vince Espejo',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX0LdePc7-tiMtnjRpZkiZroZzU2mZMTpmoZ2E5Y2mXSeK-',
#   'content': 'Nice roomie seats, tv screens, chargers, nice staff. Usually on time.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 21, 7, 24, 40),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '99572aca-cb9d-4a87-a0ad-d0ebba9264c4',
#   'userName': 'Bridget Stein',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKGRq9kMooXpIsZnLXO5JrK6c_qjthYfNOEFM_-JY1u=mo',
#   'content': 'Loved the crew!!!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 20, 22, 45, 10),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '9646991c-2e01-4fe6-9916-b5b1c55b1d34',
#   'userName': 'hermiz Hasso',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLWbBpbEBpgb9zLQ9pl6bypV4GCnN35pIm1Or7rh3bQ=mo',
#   'content': 'Great service 👏',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 20, 22, 34, 6),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '21a2152b-8e36-4b56-8046-8d119cb96f6f',
#   'userName': 'Shervonda Hairston',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI6CKGIxjG9qk8qaZoCtlFkQO4WTh43X9AcUXT4O7AH=mo',
#   'content': 'First timing flying, and it was awesome! Staff was extremely kind.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 20, 21, 21, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'cd9a7c76-740d-4d73-ad57-03901b444063',
#   'userName': 'Patricia Obrien',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJoGStpJhed8a18cQghpnSY-8CfrnyhgulXazfVRtdq=mo',
#   'content': 'Easy to use',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 20, 19, 53, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': '2053aa4c-9b2a-40a0-ae6b-e965db324ab3',
#   'userName': 'Cecilia Karpacs',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKTDKX_Mk5JZh-1xWyBYfWld4LID-wLP4V7TWCTFBPl=mo',
#   'content': "App won't download.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 20, 18, 54, 27),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '136478cd-f692-4641-80a7-38ec09f72b29',
#   'userName': 'Danger Oliver Endeveraux',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL-BWsGtgLnBbRC70byCJCnqCkMb2d265kFts4eDwFY=mo',
#   'content': 'Should have better deals last minute for some less privileged',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 20, 5, 33, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'c43341ef-538f-496d-b80b-7d26137bb88e',
#   'userName': 'Robert D. Taylor',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXe43YA9frzxiX_HViYVZJC-cisv1us-KKKCUgSYOkW1qM',
#   'content': 'The flight attendants on my short trip from CLT to EWR were rude, unprofessional, and nasty.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 19, 23, 2, 12),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '10a572ae-1a35-417f-a7a4-7ec2c9d55744',
#   'userName': 'RONNIE M',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLnJGxKmhC_AE4KafLEDo4798jEPTzUY04BmioS5cU=mo',
#   'content': "Guess what!? If in another country u have to ck in on the other airline (maybe a partner maybe a who knows but we use them ) without access to to the others assigned boardin codes etc. (Not on your AA stuff) Quote ' just goto gate' without ur qr codes .... and even if get the other qr code 'ur are NOT cked in' just 'ok' ..ummmm .. am worried. Isles in Greece were fun but home.... wanted the assurance of ck in.",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 19, 18, 46, 1),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': '3b2fa1e9-39e4-4b31-bc29-e846fa5ca6dc',
#   'userName': 'Jason Alley',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLNufvmC_2pw2XaaPQt0MTBz_AzLmaHqdTCXXng-lkC=mo',
#   'content': "I can't book a flight with this app.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 19, 18, 22, 46),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '8f2cbd6c-7547-4f98-80c7-5b18b3ece1b5',
#   'userName': 'Charles Williams',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLHZHHUwC6Bd_GFWDj0KzlwVdwrqKcSTZfKhrPQglTG=mo',
#   'content': 'Very good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 19, 17, 20, 27),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '8560f086-8bb2-424b-a0be-1d328e1af3d6',
#   'userName': 'Chris Cojack',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUS9B9wE2WTZygkHi3ZgxXPETQYtUZ_edSxDrEOzbjHuw',
#   'content': "... ughhhh cancel ed my flight and rebook then don't wanna give me a hotel",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 19, 8, 13, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '63279307-9aa5-4dde-854e-de50ac26c92a',
#   'userName': 'Sam Meyers',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIGNYo3H9leEJIApweOYsm5D69FXRseTTPNim7qwAiL=mo',
#   'content': "Won't show prices for Philippines",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 19, 7, 32, 51),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '81049ef9-ba10-4e57-82da-4701ff2ea8fa',
#   'userName': 'Rita Renee Scott',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUEM4of7AaVzCFiOlJ9X2BkU2_9mxqZ-MPXWuiMnk7K5mBO',
#   'content': 'Great flight to and fro Jamaica',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 19, 4, 13, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'b47afa14-9976-4b8d-ac47-ace9d64052e2',
#   'userName': 'Vince Martorano',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIVODFygiomDo2WNe68ifBjdvsu3d8_d5UP5KJdd-VX=mo',
#   'content': 'Slow',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 19, 3, 31, 46),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '72d97bf1-6a55-4631-9ead-049ecd841013',
#   'userName': 'Jesse Wildeman',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL2SnjVQ_Q_855kkfK-V45M4JPwVE3_Jga5WR3s9JCQ=mo',
#   'content': 'App breaks all the time, is slow and clunky and not particularly well designed. This is a major airline, how do they not have this figured out better?',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 19, 3, 12, 1),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'a82dae2f-a845-4537-a29a-f9318bb3f9ab',
#   'userName': 'Connie Bilger',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI8KOxNUMMtEgNBKGytKzK13Rsy4Kc4Txl-0PxRferP=mo',
#   'content': "Drop down selections don't work.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 19, 3, 8, 50),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '5f75575a-449d-49d1-abe5-bba496f60bc7',
#   'userName': 'Janet Thompson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKWcfuntSjGp63H-zsN6sV_lriojUhn1ICN8BD0suOA=mo',
#   'content': 'I was a bit upset about the wheelchair service. going to Phoenix and back to Bakersfield, my sister had to go find someone to transport me to the plane. in Phoenix we were left sitting for around 25 mins after we had already deplaned. Bakersfield transport was spot on',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 19, 1, 21, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'c50f476d-77d1-427c-898d-a17d2f8e57c1',
#   'userName': 'Chef Rose',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK56CGUcJUIXl3tBH3xji8ngUWHdjHznaPo6J8KcMs4=mo',
#   'content': 'always a pleasure.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 18, 23, 19, 6),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '40fe47fb-ec9c-4e0d-82dc-fb92be1dc4fa',
#   'userName': 'D H',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXGyZxcffFGh8t5TmCfS9aR4JF5vIUEI_Ud9EmerhP-VP0',
#   'content': 'Love the app. Would also love it if you could keep track of your miles-earning activity more, like in the Delta app, where they show all of your qualifying activity.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.9',
#   'at': datetime.datetime(2023, 9, 18, 22, 54, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.9'},
#  {'reviewId': '1a7d604a-b0de-42f1-9d3b-6a5d52244827',
#   'userName': 'Donna Duncan',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL5YGYn5b00v3Q3gNCRQXCjV_VVvPwUFhKivQeDYDhy=mo',
#   'content': "couldn't be more helpful",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 18, 7, 29, 26),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': '718f07c2-1854-41b9-a46a-9a097c957693',
#   'userName': 'Eric and Katie Knecht',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXCtdHK3U-wUBLjShiCk2nZJ3AB2xFMYGCup20t7uUA-l8',
#   'content': 'Meh',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 18, 5, 38, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'f448c1dd-3b80-474b-a1c2-dfd7fcbefd9c',
#   'userName': 'J Harding',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLa-vN4rUImmk_Tk56QSVtJ0vpzgO7exuN1lKon0UIJ=mo',
#   'content': "Works well. Let's me know when my bags are loaded. Nice app.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 18, 3, 5, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': '3efc87a7-d1bd-48aa-9f41-f89b66d29340',
#   'userName': 'Suzie Martin',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIGmPGQkQypsc4D9-XBB3IU_w98j7r5MbNyYyrUhXNv=mo',
#   'content': "Site doesn't say how much an upgrade to first class would be",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 18, 1, 27, 23),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '78839266-5373-43a6-95b8-e9fd4568263c',
#   'userName': 'Andy',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUkem8EKXkpaXP9DYExaw7xfbB7sHV4t-R3ocJ7VJZmDCA',
#   'content': 'Never saves my account number, connecting to WiFi is a nightmare and seriously overpopulated with ads. Get rid of the ads. Fund your app from another source.',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 18, 0, 44, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '74411cbd-4bde-4f8b-a00d-abd17286ce35',
#   'userName': 'King Bob',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJxRopltYa_5rBwPcyjal9TJ0KAv7MXluAgRqnhLvVI=mo',
#   'content': "FRONTIER's app works better than American Airlines app in 2023.. WOW!! If its not being put back into the business, what are you guys doing with all the money from your outrageous flight prices?",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 17, 20, 26, 50),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'cb7008fe-4733-4d04-84f7-3e725a9838ee',
#   'userName': 'Chris Perry',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKjaKqIeJHoPjrDEPvLdN0pXQ0EVHHgQ2YH9VKFzueg=mo',
#   'content': 'It doesnt automatically show my upcoming flights, or let me book new flights. It will let you go through motions , then will say, our system is busy, or down. I have to go through point2connect to check in, or adjust seating options.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 17, 18, 5, 14),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '9fd9293a-0b61-4ad6-a4b2-b2a3d03be339',
#   'userName': 'Smitty J',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL-I2mNIrs7QrLy7jb03p9wzPiClfkbWGwXXD3CLU9n=mo',
#   'content': "9.15-17.23; app discontinued mobile boarding pass (for last 2 days). Updating to see if this changes. Nope.. And website is offline. (650am EST, 9/17/23) YIKES! 9.8.23: app doesn't notify gate changes, when open. Previously: Traveling Yesterday ATL To DFW, selecting a notification brought up the wrong boarding pass (original departing) instead of the RETURN flight i was in line for TSA pre check. I missed that flight. Would like an in-app option to add precheck to existing flights.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 17, 16, 24, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'd1b27e1e-07f0-4530-93bf-4cab1b1bd9bc',
#   'userName': 'Bytor Snowdog',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJMj7iVU4juzZXjrfIvrYjZKYoQ_EZVr5ky3MK3uFC9=mo',
#   'content': "Too many bugs. App freezes after searching for a flight and freezes on the manage flight pages. Baggage carousel information is never posted. Often the app freezes when opening amd it takes several attempts to get it open. Not good when you're trying to board. AA should hire whoever developed United's app. It actually works.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 17, 8, 14, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'b592fe31-ee1d-472a-92ea-f3ba0ee0b068',
#   'userName': 'Johnnie Vaughn',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXeQUIAAU_eSYec3QqAgPpMAqYIOSPlQij6c9B5EyoIsP0',
#   'content': 'Only way to go...',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 17, 3, 20, 11),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '3b916d14-c707-4e40-b0af-6dcfd129ea3c',
#   'userName': 'Richard Palmer',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIwwkQbl0Fo_rkcEa1Ss0I9F_FtA_i4YS7O_UDUOtR5=mo',
#   'content': "App sucks. Doesn't work. Totally useless. Don't bother downloading.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 17, 1, 32, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'ef0e0ff0-ae8b-452f-b0ea-c6c0e67da5f6',
#   'userName': 'spurlosa1947',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKc9uReg5hyy3Rumm_G3fHaih92FzqO3pgKj57FcQo8=mo',
#   'content': 'Great flight!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 17, 0, 7, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '3fa5280f-317b-46b1-bbc0-ebbcada73ff3',
#   'userName': 'Leo Rossi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW73sXAteuxmZgOMFCABY3m1BPGnJ-rHaNdoqHhaA_uDWo',
#   'content': "AA are so cheap they hold your expired miles for ransom and sell them back to you. Would you buy them? Try to use their app to monitor your flight with a partner, say Iberia, and you'll end up with a bunch of cool aerial pictures and zero info. Personally, I find this outrageous, given the crazy money they make on ultra expensive ticket rates. They were also the first to introduce a 100 buck fee on the first checked piece of luggage way back in say 2018. Jawdropping.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 16, 23, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '78bfcd4b-2957-40ed-b3bf-d847deef2fdb',
#   'userName': 'sonya fitzpatrick',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUbzXfQLCJhQmjE4O_3wo1lZg0q0bPTo3mAZrvvjQUol8_d',
#   'content': "I'm not able to check-in. The app has sent me to the contract tracing route 8x!",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 16, 19, 36, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '97372fcc-0747-45bd-a1d2-61ee01968d1c',
#   'userName': 'Doug Shrader',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKBqXjOndQtU61gVTENiSvklGWSqv4k7QPiLgPN0l4H=mo',
#   'content': 'Great',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 16, 18, 46, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'c3bca012-1322-439f-805a-c99b96536697',
#   'userName': 'Steve Inman',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW7hLdbiZ5LB1GVlIWAlRBbVN3MBqKmlaUdIyAw1Z54mQ',
#   'content': "Loads the wrong boarding passes 50 percent of the time and now it won't load them st all or let me check in.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 16, 17, 16, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'c7900e55-17fc-4314-82e7-ca2295d9058c',
#   'userName': 'Thomas Bach',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVJmJAQxyGMwGXXzpw2OsmjWyhe-3eBEceZybNSKhl28J4',
#   'content': 'American Airlines sucks',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.12.1',
#   'at': datetime.datetime(2023, 9, 16, 9, 41, 39),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.12.1'},
#  {'reviewId': '70be42a5-8a11-4c2b-8d51-d120e012b26f',
#   'userName': 'Mechelle F',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKw4FJTwO5aL2fEp53cZ9AtHKEEkubHmd2BFESmfJjp=mo',
#   'content': 'My flight crew was great. The pilot was also great, smooth flight',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 16, 3, 28, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': 'e2e49203-5675-4393-8150-cf2e5b5e5f02',
#   'userName': 'Paul Conches',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKT1fvkSubbUdtzWRT9d38YUFB7WP1__ADPy43fK_dE=mo',
#   'content': 'Too many add',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 16, 2, 51, 5),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': 'a31b8073-5132-4038-8a0d-aa6dc7a25863',
#   'userName': 'Jabari House',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJCX7VIGXVRff5hqQqbGtNlPTq-4wl7HP-rysM4DqgX=mo',
#   'content': 'Baggage claim was very inconsistent. Moved a carry on bag that was checked early multiple terminals.',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 16, 2, 20, 57),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': 'affce715-8d59-4ef5-a500-32238975abcc',
#   'userName': 'Brent Johnson',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVn29j1w1mWzJmEv6DMKI8hlGSfiRsojlqR6jBwTZ8twg',
#   'content': 'first class seat with 3rd class service. but if you like a half glass of tap water before takeoff, this is the place for you! baggage claim at TPA another fustercluck.',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 16, 0, 45, 16),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '7f0077e1-6bbe-4093-9a10-40239bed6b4f',
#   'userName': 'jesse roberson',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVeScSYeK3H3GvFz6WHL68rwojlaLHb4YK6f9xRtUnHag',
#   'content': "The app works as expected. I haven't had any issues with it.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.16',
#   'at': datetime.datetime(2023, 9, 15, 20, 0, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.16'},
#  {'reviewId': '2dafc48a-eae0-4335-8040-4ea5822be450',
#   'userName': 'Lupe Trevino',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJYcuAK5bj0pCZLybxnA5C_HTsbbnUUOa6anFuTVXIg=mo',
#   'content': 'Friendly, nice, very helpful First time flyer',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 15, 17, 4, 27),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': '9ff91720-166a-4e5f-9855-b245147982b9',
#   'userName': 'Sergio Guzman',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLkRCPhmxXtK-t5W9KJiJTQ6RpMeHuBkzusVAbHRGsO=mo',
#   'content': 'This site is always crashing on me. Not good when you travel for work.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 15, 16, 14, 40),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': '5dbae175-4aa4-4844-8d53-35cce5a826fc',
#   'userName': 'Clayton Siemers',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLMPt6C-MsbqCgTiqPyz9TcKuBk7sUTbaMowYZZK-od=mo',
#   'content': 'AA should benchmark against the United app',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 15, 8, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': '81b8d898-4871-4ad6-86e0-0d621f3c2163',
#   'userName': 'Jodi Ketchem',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXpt64uTgNrALwU1VwkWi9iny31ClBaFPuoZkyFLy3clCZJ',
#   'content': 'Very easy to use',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2022.28.1',
#   'at': datetime.datetime(2023, 9, 15, 6, 11, 6),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2022.28.1'},
#  {'reviewId': 'eaae1e3b-6c02-4afc-9f03-7d23edee9603',
#   'userName': 'Chelsea Block',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXcFxtu5cRAO_bqTFHMUe9EOCWs7NUDUlYvlxPcW8X-anHX',
#   'content': "Can't actually click a new flight to change it. So frustrating.",
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 15, 5, 34, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': 'd29a83d2-6b5a-4ce3-ba5d-196207d1a121',
#   'userName': 'Shawn McGee',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI0hmvy2c25SSlwPmv3bFDMUS3PJ_qSoK-DI530yEV5=mo',
#   'content': "Can't get past scan passport: under any condition. Tried every light, distance, etc and won't read it.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 15, 5, 6, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': '4d007bca-b3f5-4c10-a70e-bdc5607da05a',
#   'userName': 'Melodie Ivy',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU_ltyrZBwJFFIAe44nqE3nQ2iGyaye_tAZMkk0YuiYqkPS',
#   'content': 'we had to check our bags at the gate cuz no more room on the plane. waiting at baggage claim 30 mins and still no bags.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 15, 2, 15, 4),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': '1e5cd056-6b64-4bf2-b566-c411700a84e7',
#   'userName': 'Thomas Grout',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIaVUj7w3HklQhMd0gTlweeoNkf8C-pHJO37nkMKtlt=mo',
#   'content': 'always able to get the flight and seat I want so easy to do',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 15, 1, 25),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': '3225fac0-f82d-416b-ae7a-a4664b681d3d',
#   'userName': 'Suzanne W',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWhQrznm1ROEzXcnAHRM4VYAaxKyDjl_Ce3skJ2s5qga7o',
#   'content': 'Boarding passes do not always come up.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 14, 23, 56, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': '9888a600-8114-4230-b9b1-4161568d57f2',
#   'userName': 'BRISA FOX (FOX)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWoqY2Zf0xfJf8YCR1YvVARXnS0-hTYuEVrPPAzdsXr5vA',
#   'content': 'It is not only the application that is wrong, but the entire American airlines system...After many years I bought tickets from American airlines and I was surprised that it is awful to travel with this company...',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 14, 23, 15, 39),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'a26b8f00-adc6-4a92-b2ad-c5c5cbc5c641',
#   'userName': 'Michael M.',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUieQwLO9GwdqK99UQv_wkZwRcMXacnAY8f8WGbpLh07HA',
#   'content': 'gate attendant insisted we check bag, said no more overhead baggage space. upon boarding there was space. passengers put bags in flat, sideways and generally took too much space which could have been used by passengers who needed bin space. flight attendants need to to manage their flights.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 14, 22, 5, 1),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': 'd2edd2db-412d-4f11-b94a-f10400bbb048',
#   'userName': 'Craig Ober',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI2RiyFa0TcjuH0bJtDsm12x5A5xJ3drhoMAk-6PWdT=mo',
#   'content': 'Quick...efficient 2 check in',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 14, 17, 46, 34),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': '4614713e-ce03-4e77-8e50-e96b6fe22b7e',
#   'userName': 'Hugh S',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLaO5nNx5yLjLYMAG67n5MIqHD-YfQwqQ3gM81bAty-=mo',
#   'content': "It's very annoying that the app does not let you put your tickets in Google wallet. Multiple times when I have gone to get my boarding pass the app just spins. so either I get out of line or hold up the boarding process. This is a simple problem to solve, would be nice if you did.",
#   'score': 3,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 14, 9, 27, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': 'da918d87-f180-4166-b193-cba9e0f85e52',
#   'userName': 'Sergio Martis',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUdMgOuJvJWwD_3auS5zfhCv3aEbWsNwjnu3oFW8b7koQ',
#   'content': 'I like it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.5',
#   'at': datetime.datetime(2023, 9, 14, 9, 5, 24),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.5'},
#  {'reviewId': '42b9281a-d456-47bd-9167-7daa0bcb29eb',
#   'userName': 'Somoud Barghouthy',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUlFnsRPFitMnfHjVePzEupbl83lJwfHUEp2EP3ciZD7bA',
#   'content': 'You canceled the 10:30 pm flight and provided a hotel voucher for US citizens, while others, like myself, were left to sleep at the airport. This behavior is truly disappointing and unacceptable.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 14, 8, 20, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '2e1e8d52-4752-4060-8be8-b7aa2e890cd2',
#   'userName': 'Allain Thibodeau',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ_tv3mhLe62b3Mo8fqXxeodqc3ts3xI_9PR54MMGIC=mo',
#   'content': 'been on time, LATELY',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.15',
#   'at': datetime.datetime(2023, 9, 14, 2, 40, 26),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.15'},
#  {'reviewId': '340505f1-3ae4-4e86-821e-9db4b7b266b8',
#   'userName': 'Lawrence Venable',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJO9RtbhVG3vQv1aYP-f13SISfR7li5zVkQ60YmQQ1_=mo',
#   'content': 'Not easy to understand if you are not very adept with a computer!',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 14, 2, 38, 50),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
# ...
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.7',
#   'at': datetime.datetime(2023, 4, 23, 6, 57, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.7'},
#  {'reviewId': '1e8f6798-5ea5-481e-975a-b9530aa4dff9',
#   'userName': 'Katie Evans',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocITILPfdhU7ukPQZ5XL43DfHwmlhcrwAeCXVsRXosRx=mo',
#   'content': 'My brand new suit case got ripped. Besides that it was good service',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.7',
#   'at': datetime.datetime(2023, 4, 23, 2, 11, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.7'},
#  {'reviewId': 'c181415c-8de5-460c-b063-096259a13349',
#   'userName': 'Rahul Kumar',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKnAr59eJG0UCMdkSstMeCfblK7yr9CsLXAKVZcZHxr=mo',
#   'content': 'It was not loading first of all. I thought of uninstalling it and reinstall, but it is just showing me the message as Uninstalling since last two days in Play Store. I do not have any other option to cancel it or install it again. I did restart my device too, but no luck.',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2023.7',
#   'at': datetime.datetime(2023, 4, 23, 0, 33, 10),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.7'},
#  {'reviewId': '9cad686f-6b37-4e41-8c03-e09ee3077c54',
#   'userName': 'Guido Andrés Chiappero',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVMMNsZjoBZZ_2Uuh5wTT2pH6JUT12JEJ_wXRhmpMwlYKw',
#   'content': "Awful app. Doesn't let you upload COVID documents, you hace to eat the queue for Manuel check in at the airport. Thanks for the time loss.",
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2023.7',
#   'at': datetime.datetime(2023, 4, 22, 6, 46, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.7'},
#  {'reviewId': 'de0a902e-7113-4279-a3b0-f0a487aae781',
#   'userName': 'Tanis Oakley',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLLd7dSGDtTZ9A6pwe0MIULYMwTB89-lGgwJOBD9jOs=mo',
#   'content': 'CD',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.7',
#   'at': datetime.datetime(2023, 4, 22, 5, 4, 19),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.7'},
#  {'reviewId': '58147456-ece4-437e-b9f6-5d18f0c2c5a0',
#   'userName': 'Jonathan C',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLqm6RgJr1weTKhWDLrWoZpnLrrrBJYYEc5grDKzkv5=mo',
#   'content': "April 6th update killed my ability to open boarding passes on my phone. Everything else seems to work. Select 'View Passes' and nothing happens. Please fix this. (Samsung Flip 3)",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 22, 3, 9, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': 'd0538ea3-3a87-4d40-b312-2a52e4595b9e',
#   'userName': 'sammy bolla',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWG8EapsKOqmtSaGWIR5RBAsFuYtXYwwXtXQ7ouaQC_vSI',
#   'content': 'American Airlines service is the worst always delay no more American Airline you suck',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2023.7',
#   'at': datetime.datetime(2023, 4, 21, 3, 29, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.7'},
#  {'reviewId': '734ec667-f744-4817-a6db-cdb8939f3166',
#   'userName': 'Ken Hulme',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUGJbJUk-WALwnTnaSEFLw5IFtC0dRWf01h2s9H66kF234',
#   'content': 'Not updating to show changes to my flights made hours ago!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 21, 3, 28, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': 'f4c88f4f-177f-4588-aa8a-863f379c2e95',
#   'userName': 'Ariel Garin',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWoPxihhlLDIjapG7-G0KjpL-Ynh9r5_KbbDwLciiWlgw',
#   'content': 'Amazing app. Very simple to use and provides a very streamlined ease of use for all thier passengers. I do have some suggestions however, if the luggage tracking could have its own UI within the app rather than the webpage, would be helpful on app usage. As well as Android Wear OS and Galaxy Tizen OS support, as there was Wear OS support before, for passenger convenience. Kudos to the dev team!!',
#   'score': 4,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2023.7',
#   'at': datetime.datetime(2023, 4, 21, 1, 52, 57),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.7'},
#  {'reviewId': '8f9cb834-515e-4883-8caf-e480bf171b0b',
#   'userName': 'Savi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWMD-187a4f8ZsucSMpuZEa1vLJKBYX4Df_g0BCYnW973wI',
#   'content': 'very useful and functional app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.7',
#   'at': datetime.datetime(2023, 4, 20, 23, 58, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.7'},
#  {'reviewId': 'a106c2ed-7319-48bc-b17f-b462a3f88f53',
#   'userName': 'Madaline Werleman',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUlUASALy2b0qMlwmLMFQP7yIXRkz2hOoRmJjak0XijSpgJ',
#   'content': 'a fast service and good flight',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.7',
#   'at': datetime.datetime(2023, 4, 20, 22, 46, 31),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.7'},
#  {'reviewId': '932189a2-0855-44d3-81e7-4905f35baec8',
#   'userName': 'Judie Malinen',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJANbencgMgmaa6eUqXoQbcrcHFotmVRHaVf0uzANtY=mo',
#   'content': 'no hassel checking in, both flights were great',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 20, 8, 8, 57),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': 'e92dc866-875f-4a17-9fa5-4e5ed854bafa',
#   'userName': 'Suzanne Bailey',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIPSYoXIY3TiFeLzL5XZmoVY30NqKl_CsN9QEE7qWLL=mo',
#   'content': 'freezing cold.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 20, 5, 51, 19),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': '99a49017-81ea-4754-902f-9952d2da62a8',
#   'userName': 'Coby Jones',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVjPFk-_huYFqpLHDC6anTpNmxwE50wO7v_tQPA-R08XDKS',
#   'content': 'When selecting a boarding pass, it would bring up the wrong one.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.7',
#   'at': datetime.datetime(2023, 4, 20, 4, 32, 18),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.7'},
#  {'reviewId': '531beeb4-b72a-448a-a3a6-86ed9fb9dde9',
#   'userName': 'Craig LeFevre',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXhICXDXqtW4-Re8EIhOJ5FXcdNCtgPwO8QOOPDmfhUd8nw',
#   'content': 'the app is great. planes are meh.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 20, 4, 16, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': '6e2ceca3-5eed-4ba9-95b7-c10af26b80ea',
#   'userName': 'Ms. TD Ellison',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL3KXyFnIJSjAarpytppi8bhzSn3YIt29YLviLc8jU=mo',
#   'content': "Hasn't opened in days. Uninstalled twice",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.7',
#   'at': datetime.datetime(2023, 4, 20, 2, 23, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.7'},
#  {'reviewId': '65a791cd-8115-45a7-a797-aeb0e23765dc',
#   'userName': 'Pastor David Horn',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIVxQCgv3hPgWIgjQXC4XXWPhXo-LBd5ScZnt_G3JMK=mo',
#   'content': 'world traveler',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 20, 2, 7, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': '49d841d5-9e4d-4a79-a9fd-08427e7cbed0',
#   'userName': 'Keith Bartlett',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUcKN6FwoP2G7aFJ4vUK-HhfTqtLds8WKTagsP11bT4znIk',
#   'content': 'Horrible',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2022.22',
#   'at': datetime.datetime(2023, 4, 20, 0, 13, 24),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2022.22'},
#  {'reviewId': '7e719e4e-7a6f-4ce5-a428-4549e0ebf563',
#   'userName': 'Jean F Fenelon',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKMqZt4L4UT-wbrvKGTNk3wqd1R4uMqIxmuOkDA3d49=mo',
#   'content': 'Great',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 19, 23, 54, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': '356ee426-b791-4988-a729-d9baea447241',
#   'userName': 'shane hutchens',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIFiKODkxs14nAWQgzVQjQA40aRG_f8JjfSK-5EAA71=mo',
#   'content': 'One of your fellas at the DC airport was rude for no reason, other than that no issues.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 19, 23, 18, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': '6a2beb78-3758-417a-b3b8-0182b56ef047',
#   'userName': 'Roque Zavala',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKQvqkZ-W7-kF5KVDlDQ2xGcsx6sw1xtiLipzdTLmYF=mo',
#   'content': 'best airline bar none',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 19, 22, 30, 49),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': 'b9e89af6-0ae1-4f73-8f20-ea460f659aed',
#   'userName': 'J.W. Craft',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJWfWpMol8v58Z6dHMzm62zoxhEAicKF80AV9IGGjmH=mo',
#   'content': "you can't deal with Roman numeral suffix on reservations.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 19, 19, 45, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': '8bb04ca5-7582-49f8-8f2e-f8dea78fb182',
#   'userName': 'Bart Gragg Personal',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXQKq12Mbh5IAqLW1Wet-dmNdX6uWQk0kBz34A3Su_b3hk',
#   'content': "There is no way that I can find to update contact information such as addresses, TSA#, etc. There's no obvious link to find my Profile.",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2021.12.2',
#   'at': datetime.datetime(2023, 4, 19, 17, 48, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2021.12.2'},
#  {'reviewId': '4f86583e-740e-4bde-983f-ccf6540066b5',
#   'userName': 'Cis-Mse-6-5L Cis-Mse-6-5l',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUe4dIcZVL4LAE-WT4QHbJhkgSFKN87lbxtnIEbqdx1_Ds',
#   'content': 'Itsa good app.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 4, 19, 7, 42, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '18c7c791-4e74-4955-9d31-0f4d69f4b52c',
#   'userName': 'Steven Payne',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUpq4hiwKsE8vFjq5t5Dhbl9JHd3VyoUyy0s-vAC1njPIU',
#   'content': "I didn't know I was in standby",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 19, 3, 11, 14),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': '3556fc99-8e92-48c6-81bd-859feb470e1c',
#   'userName': 'Michael',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLPsPBAOfwNb-q2wlo0XgVbObvsBAijvSoKr5_lZiAGyA=mo',
#   'content': 'Quite handy to keep up with fast changing flight information.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.7',
#   'at': datetime.datetime(2023, 4, 19, 2, 4, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.7'},
#  {'reviewId': '845858a9-965b-4ffe-8961-717f212f479a',
#   'userName': 'Derrell Rose',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKrsK3mHQLonJhxiGUcAt4PlPIz6tKNqF08OX-hN3yC=mo',
#   'content': 'old plane',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 19, 1, 53, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': '7100acf8-1ad3-4973-9d06-796dae5f7ac3',
#   'userName': 'Gina Duncan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXbIsM0FfPjLqoSKpQbSuLHEkvA_VtvgGIDqil4VwiokKk',
#   'content': 'Friendly staff clean planes. smooth rides and even got us to our destination 20 minutes early.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 19, 0, 21, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': '1dbf0e5a-23da-4066-891c-3b6ee77d342f',
#   'userName': 'Tamsin Mavric',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX3cO5JFhsps_PO3vbT_v7jLVjWmAVF-Y4mQtNUqyy3jEY',
#   'content': "Absolutely Useless! Won't scan my passport. Was trying to check in. Useless.Useless.Useless.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 18, 21, 0, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': 'a9195264-8e29-47c3-a431-12048719e0d6',
#   'userName': 'Priscilla Quinn',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIDaDL6xg1zhOg_QUoN2fNFgMoco2cUWk2-I73cD1GoCA=mo',
#   'content': 'Great flights!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 18, 8, 36, 19),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': '6537a91b-fa93-4fba-93ee-2a7cf2db4e95',
#   'userName': 'adrien jacobs',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUkD4ihhx3Bc_Nv4fUFH1d94SzlL2RqGblzkBRVp_3R9ds',
#   'content': "I love flying with AA! it's the most comfortable and convenient service for flying.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 18, 7, 26, 50),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': 'c5b86efa-9ae5-418b-a295-df2b9c8b43d0',
#   'userName': 'Antwone Stafford',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJueiG05WkPgu01fviAQZVuUukx8N39ZyfYSiXeGor9=mo',
#   'content': 'great overall service',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 18, 6, 20, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  {'reviewId': '3e95326b-e198-49a8-a4f0-c7352e4d900c',
#   'userName': 'Jared Byrne',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWqZX2JBMsm8kgM7ppGJ671IPi_OBOcgbshy8NDbISedrI',
#   'content': 'I don\'t used this app very much, b/c I don\'t see the point. I\'ve spent over an hour trying to sign-in to a flight, which included time on the phone (with two different staff). Overall, aside from being told "thanks for being a reward member" repeatedly, I\'ve had to renter my information multiple times, and despite everything being green/marked "complete" it still won\'t let me check-in. The staff solved this by saying I need to \'get to the airport a couple hours earlier than normal\'. Pointless?!',
#   'score': 1,
#   'thumbsUpCount': 88,
#   'reviewCreatedVersion': '2023.6',
#   'at': datetime.datetime(2023, 4, 18, 6, 19, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2023.6'},
#  ...]

# %%
df=pd.DataFrame(us_reviews)
df.head()
# Out:
#                                reviewId          userName  \
# 0  7e5f1830-345d-4b88-80c9-4f94b30d7818      Denise Serna
# 1  be46c94d-88ef-4834-99d2-a97ec26cf51e   Isabella Garcia
# 2  d39456f4-6da0-4d48-a463-50d30c0ac995             Jon S
# 3  0dc819e3-ee8b-44b5-a5e5-cd94937e1195  Kenneth Mckinney
# 4  d2ed0d59-027f-40e6-bd74-38776bda4452     Alicia Mendez
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0                  Great flight & smooth ride to LAX      5              0
# 1  Never ever show me information about my flight...      1              0
# 2  Had to uninstall the app to check-in for my fl...      1              0
# 3                                 worst company ever      1              0
# 4  exceptional landing at DFW this evening by our...      5              0
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0              2023.16 2023-09-24 10:46:17         None       NaT    2023.16
# 1              2023.16 2023-09-24 09:58:53         None       NaT    2023.16
# 2              2023.16 2023-09-24 06:59:53         None       NaT    2023.16
# 3              2023.16 2023-09-24 06:00:21         None       NaT    2023.16
# 4              2023.15 2023-09-24 05:56:47         None       NaT    2023.15

# %%
df.shape
# Out:
# (14548, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14548 entries, 0 to 14547
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              14548 non-null  object
#  1   userName              14548 non-null  object
#  2   userImage             14548 non-null  object
#  3   content               14531 non-null  object
#  4   score                 14548 non-null  int64
#  5   thumbsUpCount         14548 non-null  int64
#  6   reviewCreatedVersion  12744 non-null  object
#  7   at                    14548 non-null  datetime64[ns]
#  8   replyContent          2114 non-null   object
#  9   repliedAt             2114 non-null   datetime64[ns]
#  10  appVersion            12744 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 1.2+ MB
